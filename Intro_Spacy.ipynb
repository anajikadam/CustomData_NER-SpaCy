# %% [markdown]
# Biomedical Named Entity Recognition with Transformers
#
#
# https://www.youtube.com/watch?v=xpiDPdBpS18&list=LL&index=5&t=190s
#
#
#
#
#
# ---
#
#
#
# Train Custom NER with Spacy v3.0
#
#
# https://www.youtube.com/watch?v=9mXoGxAn6pM&list=LL&index=4&t=214s
#
# ---
# Custom NER with spaCy v3 Tutorial | Free NER Data Annotation | Named Entity Recognition Tutorial
#
#
# https://www.youtube.com/watch?v=p_7hJvl7P2A&list=LL&index=3&t=312s
#
#
# ---
# Learn How to Build a Custom Named Entity Recognition (NER) model using spacy
#
#
# https://www.youtube.com/watch?v=YLQvVpCXpbU&list=LL&index=2&t=3s
#
# ---

# %% [markdown]
# Custom NER with spaCy v3 Tutorial | Free NER Data Annotation | Named Entity Recognition Tutorial
# https://www.youtube.com/watch?v=p_7hJvl7P2A&list=WL&index=2&t=312s

# %% [markdown]
# https://tecoholic.github.io/ner-annotator/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
https://spacy.io/usage/training

# %%
https://github.com/amrrs/custom-ner-with-spacy3?tab=readme-ov-file
